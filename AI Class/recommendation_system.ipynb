# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
rating = pd.read_csv('BX-Book-Ratings.csv', sep = ';', encoding= 'unicode_escape', error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
rating
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books = pd.read_csv('BX-Books.csv', sep = ';', encoding= 'unicode_escape', error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 9\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# ...

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
users = pd.read_csv('BX-Users.csv', sep = ';', encoding= 'unicode_escape', error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
books.shape
# Out:
# (271360, 8)

# %%
rating.shape
# Out:
# (1149780, 3)

# %%
users.shape
# Out:
# (278858, 3)

# %%
books = books.iloc[:,:5]

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
books['Year-Of-Publication'].unique()
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, '2000', '1982', '1988',
#        '1980', '0', '1986', '1981', '1978', '1991', '1989', '1994',
#        '1992', '1993', '1979', '1984', '1977', '1983', '1998', '1996',
#        '1997', '2001', '1995', '2002', '1999', '1987', '2004', '2003',
#        '1990', '1985', '1960', '1970', '1976', '1973', '1971', '1975',
#        '1955', '1967', '1940', '1968', '1957', '1965', '1930', '1972',
# ...

# %%
books.loc[books['Year-Of-Publication'] == 'DK Publishing Inc']
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        Book-Author Year-Of-Publication  \
# 209538        2000   DK Publishing Inc
# 221678        2000   DK Publishing Inc
#
#                                                 Publisher
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...

# %%
books = books[(books['Year-Of-Publication'] != 'DK Publishing Inc') & (books['Year-Of-Publication'] != 'Gallimard'  ) & (books['Year-Of-Publication'] != 'Canterbury Press')]

# %%
books['Year-Of-Publication'].unique()
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, '2000', '1982', '1988',
#        '1980', '0', '1986', '1981', '1978', '1991', '1989', '1994',
#        '1992', '1993', '1979', '1984', '1977', '1983', '1998', '1996',
#        '1997', '2001', '1995', '2002', '1999', '1987', '2004', '2003',
#        '1990', '1985', '1960', '1970', '1976', '1973', '1971', '1975',
#        '1955', '1967', '1940', '1968', '1957', '1965', '1930', '1972',
# ...

# %%
books.dtypes
# Out:
# ISBN                   object
# Book-Title             object
# Book-Author            object
# Year-Of-Publication    object
# Publisher              object
# dtype: object

# %%
books['Year-Of-Publication'] = pd.to_numeric(books['Year-Of-Publication'])

# %%
books.dtypes
# Out:
# ISBN                   object
# Book-Title             object
# Book-Author            object
# Year-Of-Publication     int64
# Publisher              object
# dtype: object

# %%
books.dropna(subset = ['Publisher'], inplace = True)

# %%
books['Publisher'].isnull().sum()
# Out:
# 0

# %%
users.dtypes
# Out:
# User-ID       int64
# Location     object
# Age         float64
# dtype: object

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
age_counts = users["Age"].value_counts()

fig = px.bar(age_counts, title="Age distribution")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
age_counts
# Out:
# 24.0     5687
# 25.0     5618
# 26.0     5547
# 23.0     5456
# 27.0     5383
#          ...
# 168.0       1
# 132.0       1
# 159.0       1
# 186.0       1
# 127.0       1
# Name: Age, Length: 165, dtype: int64

# %%
users.loc[(users['Age'] > 90) | (users['Age'] < 5)] = np.nan

# %%
users.Age.isna().sum()
# Out:
# 112074

# %%
#users['Age'] = users['Age'].fillna(users['Age'].mean())

# %%
median = users["Age"].median()
std = users["Age"].std()
is_null = users["Age"].isnull().sum()
rand_age = np.random.randint(median - std, median + std, size = is_null)
age_slice = users["Age"].copy()
age_slice[pd.isnull(age_slice)] = rand_age
users["Age"] = age_slice
users["Age"] = users["Age"].astype(int)

# %%
users.Age.isna().sum()
# Out:
# 0

# %%
age_counts = users["Age"].value_counts()

fig = px.bar(age_counts, title="Age distribution")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
rating.ISBN = rating.ISBN.str.replace(r'[^\w\d]+', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %%
#ratings ds should just have books which exist in our dataset
rating = rating[rating['ISBN'].isin(books['ISBN'])]

# %%
rating.shape[0]
#from 1149780 to new value
# Out:
# 1031463

# %%
rating = rating[rating['User-ID'].isin(users['User-ID'])]

# %%
rating.shape[0]
#from 1031463 to new value
# Out:
# 1026483

# %%
rating['Book-Rating'].unique()
# Out:
# array([ 0,  5,  3,  6,  7,  9,  8, 10,  1,  4,  2])

# %%
rating_exp = rating[rating['Book-Rating'] != 0]

# %%
rating_exp
# Out:
#          User-ID        ISBN  Book-Rating
# 1         276726  0155061224            5
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# 8         276744  038550120X            7
# 16        276747  0060517794            9
# ...          ...         ...          ...
# 1149771   276704  0743211383            7
# 1149773   276704  0806917695            5
# 1149775   276704  1563526298            9
# 1149777   276709  0515107662           10
# 1149778   276721  0590442449           10
#
# [382294 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(data = rating_exp, x = 'Book-Rating')

# %%
rating_imp = rating[rating['Book-Rating'] == 0]

# %%
rating_imp.shape
# Out:
# (644189, 3)

# %%
data = pd.merge(rating, users, on='User-ID', how='inner')

# %%
data
# Out:
#          User-ID        ISBN  Book-Rating                        Location  Age
# 0         276725  034545104X            0               tyler, texas, usa   33
# 1         276726  0155061224            5        seattle, washington, usa   26
# 2         276727  0446520802            0   h, new south wales, australia   16
# 3         276729  052165615X            3            rijeka, n/a, croatia   16
# 4         276729  0521795028            6            rijeka, n/a, croatia   16
# ...          ...         ...          ...                             ...  ...
# 1026478   276704  0876044011            0          cedar park, texas, usa   44
# 1026479   276704  1563526298            9          cedar park, texas, usa   44
# 1026480   276706  0679447156            0          quebec, quebec, canada   18
# 1026481   276709  0515107662           10  mannington, west virginia, usa   38
# 1026482   276721  0590442449           10   providence, rhode island, usa   14
#
# ...

# %%
data = pd.merge(data, books, on='ISBN', how='inner')

# %%
data
# Out:
#          User-ID        ISBN  Book-Rating                   Location  Age  \
# 0         276725  034545104X            0          tyler, texas, usa   33
# 1           2313  034545104X            5      cincinnati, ohio, usa   23
# 2           6543  034545104X            0   strafford, missouri, usa   34
# 3          10314  034545104X            9     beaverton, oregon, usa   38
# 4          23768  034545104X            0   st. louis, missouri, usa   45
# ...          ...         ...          ...                        ...  ...
# 1026478   276688  0517145553            0  fort lee, new jersey, usa   38
# 1026479   276688  1575660792            7  fort lee, new jersey, usa   38
# 1026480   276690  0590907301            0         wakeman, ohio, usa   43
# 1026481   276704  0679752714            0     cedar park, texas, usa   44
# 1026482   276704  0806917695            5     cedar park, texas, usa   44
#
#                                                 Book-Title      Book-Author  \
# ...

# %%
print('Number of books: ', data['ISBN'].nunique())
# Out:
# Number of books:  269414

# %%
print('Number of users: ',data['User-ID'].nunique())
# Out:
# Number of users:  91775

# %%
data.isnull().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Location               0
# Age                    0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              0
# dtype: int64

# %%
data['Book-Rating'] = data['Book-Rating'].replace(0, None)

# %%
data['Book-Rating'].mean()
# Out:
# 7.5523715443899215

# %%
sns.distplot(data['Year-Of-Publication'], kde=False, hist_kws={"range": [1945,2020]})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
data['Location'] = data['Location'].apply(lambda s: str(s).split(',')[-1])

# %%
data.groupby('Location')['Book-Rating'].count().sort_values(ascending=False).head(10)
# Out:
# Location
#  usa               743306
#  canada             92816
#  united kingdom     32963
#  germany            27444
#                     24182
#  australia          17768
#  spain              14773
#  n/a                11186
#  france             10658
#  portugal            6899
# Name: Book-Rating, dtype: int64

# %%
data['Year-Of-Publication'] = data['Year-Of-Publication'].fillna(2099, downcast = 'infer')

# %%
data[['Book-Author', 'Publisher']] = data[['Book-Author', 'Publisher']].fillna('Unknown')

# %%
data[['Book-Author', 'Publisher']].isnull().sum()
# Out:
# Book-Author    0
# Publisher      0
# dtype: int64

# %%
# !pip install -U numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 29.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 40.8 MB/s
# ...
#      |████████████████████████████████| 182 kB 22.3 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 41.5 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=51193c72b7b8be5fe790ab6c94e3f06881006cf143a3b20cb369d0a7c3939b2b
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# ...

# %%
#content based recommendation system
import matplotlib.pyplot as plt
import numpy as np
from sentence_transformers import SentenceTransformer
import pandas as pd
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'sans-serif' 
plt.rcParams['font.serif'] = 'Ubuntu' 
plt.rcParams['font.monospace'] = 'Ubuntu Mono' 
plt.rcParams['font.size'] = 14 
plt.rcParams['axes.labelsize'] = 12 
plt.rcParams['axes.labelweight'] = 'bold' 
plt.rcParams['axes.titlesize'] = 12 
plt.rcParams['xtick.labelsize'] = 12 
plt.rcParams['ytick.labelsize'] = 12 
plt.rcParams['legend.fontsize'] = 12 
plt.rcParams['figure.titlesize'] = 12 
plt.rcParams['image.cmap'] = 'jet' 
plt.rcParams['image.interpolation'] = 'none' 
plt.rcParams['figure.figsize'] = (12, 10) 
plt.rcParams['axes.grid']=True
plt.rcParams['lines.linewidth'] = 2 
plt.rcParams['lines.markersize'] = 8
colors = ['xkcd:pale orange', 'xkcd:sea blue', 'xkcd:pale red', 'xkcd:sage green', 'xkcd:terra cotta', 'xkcd:dull purple', 'xkcd:teal', 'xkcd: goldenrod', 'xkcd:cadet blue',
'xkcd:scarlet']

# %%
data
# Out:
#          User-ID        ISBN  Book-Rating Location  Age  \
# 0         276725  034545104X            0      usa   33
# 1           2313  034545104X            5      usa   23
# 2           6543  034545104X            5      usa   34
# 3          10314  034545104X            9      usa   38
# 4          23768  034545104X            9      usa   45
# ...          ...         ...          ...      ...  ...
# 1026478   276688  0517145553            8      usa   38
# 1026479   276688  1575660792            7      usa   38
# 1026480   276690  0590907301            7      usa   43
# 1026481   276704  0679752714            7      usa   44
# 1026482   276704  0806917695            5      usa   44
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
data.isnull().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Location               0
# Age                    0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# dtype: int64

# %%
rating = data.copy()
rating["Book-Rating"].replace(0.0,None,inplace=True)

# %%
 #getting ratings greater than 6
# df = df[df['Book-Rating'] >= 6]

# %%
#focusing on books which have atleast 5 ratings
#df = df.groupby('ISBN').filter(lambda x: len(x) >= 5)

# %%
#focusing on users who have rated atleast 5 books, to avoid overfitting the model
#df = df.groupby('User-ID').filter(lambda x: len(x) >= 5)

# %% [markdown]
# Recommender 1: Popularity based

# %%
rec1=pd.DataFrame(rating.groupby(["ISBN","Book-Title","Book-Author"])["Book-Rating"].sum().sort_values(ascending=False).head(10))
rec1
# Out:
#                                                                               Book-Rating
# ISBN       Book-Title                                         Book-Author
# 0971880107 Wild Animus                                        Rich Shapero          11214
# 0316666343 The Lovely Bones: A Novel                          Alice Sebold          10481
# 0385504209 The Da Vinci Code                                  Dan Brown              7434
# 0312195516 The Red Tent (Bestselling Backlist)                Anita Diamant          5915
# 0060928336 Divine Secrets of the Ya-Ya Sisterhood: A Novel    Rebecca Wells          5754
# 0142001740 The Secret Life of Bees                            Sue Monk Kidd          5208
# 059035342X Harry Potter and the Sorcerer's Stone (Harry Po... J. K. Rowling          5044
# 067976402X Snow Falling on Cedars                             David Guterson         4783
# 0446672211 Where the Heart Is (Oprah's Book Club (Paperback)) Billie Letts           4754
# ...

# %% [markdown]
# Recommender 2: CF Based: similar people, similar taste

# %%
#500 users who have rated the most
top_index=rating["User-ID"].value_counts().sort_values(ascending=False).head(500).index
top_index
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#              96448,  10819, 164465, 191187, 131837, 135458, 124078,  85701,
#                254, 263163],
#            dtype='int64', length=500)

# %%
df=rating[rating["User-ID"].isin(top_index)]
df.head(20)
# Out:
#     User-ID        ISBN  Book-Rating   Location  Age            Book-Title  \
# 2      6543  034545104X            5        usa   34  Flesh Tones: A Novel
# 4     23768  034545104X            9        usa   45  Flesh Tones: A Novel
# 6     28523  034545104X            9        usa   24  Flesh Tones: A Novel
# 14    77940  034545104X            8   malaysia   19  Flesh Tones: A Novel
# 15    81977  034545104X            8        usa   34  Flesh Tones: A Novel
# 17    98391  034545104X            9        usa   52  Flesh Tones: A Novel
# 20   123981  034545104X            5        usa   46  Flesh Tones: A Novel
# 26   135045  034545104X            7        usa   29  Flesh Tones: A Novel
# 30   145451  034545104X            7        usa   63  Flesh Tones: A Novel
# 41   208406  034545104X            6        usa   30  Flesh Tones: A Novel
# 46   227447  034545104X            3        usa   38  Flesh Tones: A Novel
# ...

# %%
idcount=df["User-ID"].value_counts()

# %%
df121=df[df["User-ID"].isin(idcount[idcount>=1500].index)]

# %%
zxc=df121.groupby("Book-Title")["Book-Rating"].sum().reset_index()
zxc.head()
# Out:
#                                           Book-Title  Book-Rating
# 0   A Light in the Storm: The Civil War Diary of ...            7
# 1                              Always Have Popsicles            9
# 2               Apple Magic (The Collector's series)           10
# 3   Beyond IBM: Leadership Marketing and Finance ...           10
# 4                                       Dark Justice           10

# %%
zxc=zxc[zxc["Book-Rating"]>200]

# %%
df_mat=df121[df121["Book-Title"].isin(zxc["Book-Title"])].reset_index()
df_mat
# Out:
#         index  User-ID        ISBN  Book-Rating Location  Age  \
# 0          61   278418  0446520802            5      usa   27
# 1          67    11676  0446520802           10      n/a   28
# 2          72    23768  0446520802            6      usa   45
# 3          98   102967  0446520802            9      usa   54
# 4         130   185233  0446520802            7      usa   31
# ...       ...      ...         ...          ...      ...  ...
# 1232   951566   189334  0688057624           10   canada   49
# 1233   967836   189835  0886825075            5      usa   24
# 1234   996564   227447  0694522899            6      usa   38
# 1235   998413   230522  0517056992            8      usa   52
# 1236  1000154   232131  1558002669           10      usa   44
#
#                   Book-Title           Book-Author  Year-Of-Publication  \
# 0               The Notebook       Nicholas Sparks                 1996
# 1               The Notebook       Nicholas Sparks                 1996
# ...

# %%
np.where(df_mat.index.duplicated())
# Out:
# (array([], dtype=int64),)

# %%
df_mat["Book-Rating"].fillna("", inplace=True)
